# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene':  20}
hygeine = establishments.find(query)
# Use count_documents to display the number of documents in the result
print("Number of Hygienes =20: ", establishments.count_documents(query))
print()
print("First result")
# Display the first document in the results using pprint
for i in range(1):
    pprint(hygeine[i])
# Out:
# Number of Hygienes =20:  0
#
# First result
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 10
#       8 # Display the first document in the results using pprint
#       9 for i in range(1):
# ---> 10     pprint(hygeine[i])
#
# File c:\Users\vocat\anaconda3\envs\dev\lib\site-packages\pymongo\cursor.py:757, in Cursor.__getitem__(self, index)
#     755     for doc in clone:
#     756         return doc
# --> 757     raise IndexError("no such item for Cursor instance")
#     758 raise TypeError("index %r cannot be applied to Cursor instances" % index)
#
# IndexError: no such item for Cursor instance

# %%
# Convert the result to a Pandas DataFrame
chase = list(establishments.find(query))
chase_pd = pd.DataFrame(chase)
# Display the number of rows in the DataFrame
print("Number of rows: ", len(chase_pd))
# Display the first 10 rows of the DataFrame
chase_pd.head(10)
# Out:
# Number of rows:  87
#                         _id   FHRSID  ChangesByServerID  \
# 0  665e724f5e1cb5fa5c64b8fc  1069652                  0
# 1  665e724f5e1cb5fa5c64b923   695223                  0
# 2  665e724f5e1cb5fa5c64b93a  1380578                  0
# 3  665e724f5e1cb5fa5c64b958   694609                  0
# 4  665e724f5e1cb5fa5c64b96f   695241                  0
# 5  665e724f5e1cb5fa5c64b970   694478                  0
# 6  665e724f5e1cb5fa5c64b976   909912                  0
# 7  665e724f5e1cb5fa5c64b991   694482                  0
# 8  665e724f5e1cb5fa5c64b992   695204                  0
# 9  665e724f5e1cb5fa5c64b9ba  1211907                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 1             PI/000178842                              Iceland
# 2                    14425  Howe and Co Fish and Chips - Van 17
# 3             PI/000116619                            Volunteer
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName':{'$regex': 'London'},'RatingValue':  {'$gte' : 4}}
rating = establishments.find(query)
# Use count_documents to display the number of documents in the result
print("Number of Ratings >4: ", establishments.count_documents(query))
print()
print("First result")
# Display the first document in the results using pprint
for i in range(1):
    pprint(rating[i])
# Out:
# Number of Ratings >4:  33
#
# First result
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('665e724f5e1cb5fa5c647b0d'),
#  'geocode': {'latitude': 51.369321, 'longitude': 0.508551},
# ...

# %%
# Convert the result to a Pandas DataFrame
status = list(establishments.find(query))
status_pd = pd.DataFrame(status)
# Display the number of rows in the DataFrame
print("Number of rows: ", len(status_pd))
# Display the first 10 rows of the DataFrame
chase_pd.head(10)
# Out:
# Number of rows:  33
#                         _id   FHRSID  ChangesByServerID  \
# 0  665e724f5e1cb5fa5c64b8fc  1069652                  0
# 1  665e724f5e1cb5fa5c64b923   695223                  0
# 2  665e724f5e1cb5fa5c64b93a  1380578                  0
# 3  665e724f5e1cb5fa5c64b958   694609                  0
# 4  665e724f5e1cb5fa5c64b96f   695241                  0
# 5  665e724f5e1cb5fa5c64b970   694478                  0
# 6  665e724f5e1cb5fa5c64b976   909912                  0
# 7  665e724f5e1cb5fa5c64b991   694482                  0
# 8  665e724f5e1cb5fa5c64b992   695204                  0
# 9  665e724f5e1cb5fa5c64b9ba  1211907                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 1             PI/000178842                              Iceland
# 2                    14425  Howe and Co Fish and Chips - Van 17
# 3             PI/000116619                            Volunteer
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

penny = {'BusinessName':'Volunteer'}
fields = {'geocode.latitude', 'geocode.longitude'}
penny_points = list(establishments.find(penny, fields))
pprint(penny_points)
print("Hard coding these b/c once ^ again, I struggle with ^ the sub-tionaries... ")
print("")

degree_search = 0.01
latitude = 51.490142
longitude = 0.08384

query = {'RatingValue': 5,  'geocode.latitude': {'$lte' : latitude + degree_search, '$gte' : latitude - degree_search},
                            'geocode.longitude': {'$lte' : longitude + degree_search, '$gte' : longitude - degree_search}
        }
sort = [('scores.Hygeine', 1)]
limit = 5

# Print the results
near_results = list(establishments.find(query).sort(sort).limit(limit))
pprint(near_results)
# Out:
# [{'_id': ObjectId('665e724f5e1cb5fa5c64b958'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208}}]
# Hard coding these b/c once ^ again, I struggle with ^ the sub-tionaries...
#
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': 5,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
# ...

# %%
# Convert result to Pandas DataFrame
near_df = pd.DataFrame(near_results)
near_df.head()
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  665e724f5e1cb5fa5c64b958   694609                  0
# 1  665e724f5e1cb5fa5c64b96f   695241                  0
# 2  665e724f5e1cb5fa5c64b923   695223                  0
# 3  665e724f5e1cb5fa5c64b8fc  1069652                  0
# 4  665e724f5e1cb5fa5c64b93a  1380578                  0
#
#   LocalAuthorityBusinessID                         BusinessName  \
# 0             PI/000116619                            Volunteer
# 1             PI/000179088              Plumstead Manor Nursery
# 2             PI/000178842                              Iceland
# 3             PI/000206841   TIWA N TIWA African Restaurant Ltd
# 4                    14425  Howe and Co Fish and Chips - Van 17
#
#                             BusinessType  BusinessTypeID  \
# 0                      Pub/bar/nightclub            7843
# 1                        Caring Premises               5
# 2  Retailers - supermarkets/hypermarkets            7840
# ...

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest
match = {'$match': {'scores.Hygiene': 0}}
group = {'$group': {'_id': '$LocalAuthorityName', 'count': {'$sum': 1}}}
sort = {'$sort': {'count': -1}}
pipeline = [match, group, sort]
# Print the number of documents in the result
hi_gene = list(establishments.aggregate(pipeline))
print("Number of Local Authorities: ", len(hi_gene))
print("")
# Print the first 10 results
for i in range(10):
    pprint(hi_gene[i])
# Out:
# Number of Local Authorities:  55
#
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
sum_df = pd.DataFrame(hi_gene)
# Display the number of rows in the DataFrame
print(f"Number of Local Authorities: {len(sum_df)}")
print("")
# Display the first 10 rows of the DataFrame
sum_df.head(10)
# Out:
# Number of Local Authorities: 55
#                _id  count
# 0           Thanet   1130
# 1        Greenwich    882
# 2        Maidstone    713
# 3           Newham    711
# 4            Swale    686
# 5       Chelmsford    680
# 6           Medway    672
# 7           Bexley    607
# 8  Southend-On-Sea    586
# 9         Tendring    542
